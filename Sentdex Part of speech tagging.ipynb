# %% [markdown]
# **part-of-speech (PoS)**
#
# The part of speech explains how a word is used in a sentence. There are eight main parts of speech - nouns, pronouns, adjectives, verbs, adverbs, prepositions, conjunctions and interjections.
#
# **Noun (N)**- Daniel, London, table, dog, teacher, pen, city, happiness, hope
#
# Verb (V) **bold text**- go, speak, run, eat, play, live, walk, have, like, are, is
#
# **Adjective(ADJ)**- big, happy, green, young, fun, crazy, three
#
# **Adverb(ADV)**- slowly, quietly, very, always, never, too, well, tomorrow
#
# **Preposition (P)**- at, on, in, from, with, near, between, about, under
#
# **Conjunction (CON)**- and, or, but, because, so, yet, unless, since, if
#
# **Pronoun(PRO)**- I, you, we, they, he, she, it, me, us, them, him, her, this
#
# **Interjection (INT)**- Ouch! Wow! Great! Help! Oh! Hey! Hi!

# %% [markdown]
#    Most POS are divided into sub-classes. POS Tagging simply means labeling words with their appropriate Part-Of-Speech.

# %% [markdown]
# https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/?completed=/stemming-nltk-tutorial/
#
#
#
#  A part-of-speech (PoS) tagger is a software tool that labels words as one of several categories to identify the word's function in a given language. ... Part-of-speech categories include noun, verb, article, adjective, preposition, pronoun, adverb, conjunction and interjection.
#
# POS tag list:
#
# CC	coordinating conjunction
#
# CD	cardinal digit
#
# DT	determiner
#
# EX	existential there (like: "there is" ... think of it like "there exists")
#
# FW	foreign word
#
# IN	preposition/subordinating conjunction
#
# JJ	adjective	'big'
#
# JJR	adjective, comparative	'bigger'
#
# JJS	adjective, superlative	'biggest'
# .....................etc

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %% [markdown]
# **PunktSentenceTokenizer**
#
# PunktSentenceTokenizer is the abstract class for the default sentence tokenizer, i.e. sent_tokenize(), provided in NLTK
#
# The PunktSentenceTokenizer is an unsupervised trainable model. This means it can be trained on unlabeled data(text) that is the text not split into sentences.
#
# Behind the scenes, PunktSentenceTokenizer is learning the abbreviations in the text. This is the mechanism that the tokenizer uses to decide where to “cut”

# %%
nltk.download('state_union')

train_text = state_union.raw("2005-GWBush.txt")  #Union address from 2005
sample_text = state_union.raw("2006-GWBush.txt") #Union address from 2006

# %%
train_text

# %% [markdown]
# Train the "train_text" using Punkt tokenizer like:

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(train_text)

custom_sent_tokenizer

# %%
#Then we can actually tokenize, using: custom_sent_tokenizer

tokenized = custom_sent_tokenizer.tokenize(sample_text)
tokenized[:5]

# %% [markdown]
# Part of speech tagging script by creating a function that will run through and tag all of the parts of speech per sentence like so

# %%
nltk.download('averaged_perceptron_tagger')

def process_content():
    try:
        for i in tokenized[:5]:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            print(tagged)

    except Exception as e:
        print(str(e))


process_content()
